# %%
# Import python libraries
import pandas as pd
import numpy as np
# Import libraries for visualization 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Configuring styles
sns.set_style("darkgrid")
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (12, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# !pip install chart-studio
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.0 MB/s
# ...

# %%
import chart_studio
username='pinaki2000'
api_key='QYSMGMVU1lOXPuQMx05W'
chart_studio.tools.set_credentials_file(username=username,
                                        api_key=api_key)

# %%
df2 = pd.read_csv('/content/laptop_price.csv',encoding='latin-1')

# %%
df2.head()
# Out:
#    laptop_ID Company      Product  ...  OpSys  Weight Price_euros
# 0          1   Apple  MacBook Pro  ...  macOS  1.37kg     1339.69
# 1          2   Apple  Macbook Air  ...  macOS  1.34kg      898.94
# 2          3      HP       250 G6  ...  No OS  1.86kg      575.00
# 3          4   Apple  MacBook Pro  ...  macOS  1.83kg     2537.45
# 4          5   Apple  MacBook Pro  ...  macOS  1.37kg     1803.60
#
# [5 rows x 13 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df2.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df2.corr()
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.087796     0.067830
# Inches       -0.087796  1.000000     0.068197
# Price_euros   0.067830  0.068197     1.000000

# %%
df2.shape
# Out:
# (1303, 13)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df2.corr(), annot=True,cmap ='RdYlGn')

# %%
fig = px.bar(df2, 
                   x="Company", 
                   #marginal='box', 
                   #y="No. of suicides per state", 
                   title='Distribution of Companies of Laptop',
                   color_discrete_sequence=['red'])

fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="11616653-7344-4e80-86ed-9d7f64992df5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11616653-7344-4e80-86ed-9d7f64992df5")) {
#                     Plotly.newPlot(
#                         '11616653-7344-4e80-86ed-9d7f64992df5',
# ...

# %%
import chart_studio.plotly as py
import chart_studio.tools as tls

# %%
py.plot(fig, filename="laptop1", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/10/'

# %%
fig = px.histogram(df2, 
                   x='Price_euros', 
                   marginal='box', 
                   color='Ram', 
                   #hover_data=['Company'], 
                   #color_discrete_sequence=['green', 'grey'], 
                   title='Ram vs Price')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cff8dc4-8547-4e97-9a3a-002330b77a36" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cff8dc4-8547-4e97-9a3a-002330b77a36")) {
#                     Plotly.newPlot(
#                         '6cff8dc4-8547-4e97-9a3a-002330b77a36',
# ...

# %%
py.plot(fig, filename="laptop2", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/12/'

# %%
fig = px.scatter(df2, 
                   x='Price_euros', 
                   #marginal='box', 
                   color='Ram', 
                   hover_data=['Company'], 
                   #color_discrete_sequence=['green', 'grey'], 
                   title='Ram vs Price')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="04cb0618-83bc-4aa0-96cb-bc8bcb7df9b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04cb0618-83bc-4aa0-96cb-bc8bcb7df9b5")) {
#                     Plotly.newPlot(
#                         '04cb0618-83bc-4aa0-96cb-bc8bcb7df9b5',
# ...

# %%
py.plot(fig, filename="laptop3", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/14/'

# %%
fig = px.scatter(df2, 
                   x='Price_euros', 
                   #marginal='box', 
                   color='Cpu', 
                   hover_data=['Company'], 
                   #color_discrete_sequence=['green', 'grey'], 
                   title='CPU vs Price')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="867c2cbd-8f11-49f0-bff0-f7d7d515138d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("867c2cbd-8f11-49f0-bff0-f7d7d515138d")) {
#                     Plotly.newPlot(
#                         '867c2cbd-8f11-49f0-bff0-f7d7d515138d',
# ...

# %%
py.plot(fig, filename="laptop4", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/16/'

# %%
fig = px.histogram(df2, 
                   x='Price_euros', 
                   marginal='box', 
                   color='Cpu', 
                   #hover_data=['Company'], 
                   #color_discrete_sequence=['green', 'grey'], 
                   title='CPU vs Price')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="936a89ac-6030-4f7c-bfe4-dfd2e03b97fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("936a89ac-6030-4f7c-bfe4-dfd2e03b97fe")) {
#                     Plotly.newPlot(
#                         '936a89ac-6030-4f7c-bfe4-dfd2e03b97fe',
# ...

# %%
py.plot(fig, filename="laptop5", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/18/'

# %%
fig = px.histogram(df2, 
                   x='Price_euros', 
                   marginal='box', 
                   color='Gpu', 
                   #hover_data=['Company'], 
                   #color_discrete_sequence=['green', 'grey'], 
                   title='GPU vs Price')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="162a72f1-c684-4c05-88b6-9697f1da674e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("162a72f1-c684-4c05-88b6-9697f1da674e")) {
#                     Plotly.newPlot(
#                         '162a72f1-c684-4c05-88b6-9697f1da674e',
# ...

# %%
py.plot(fig, filename="laptop6", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/21/'

# %%
fig = px.bar(df2, 
                   x="OpSys", 
                   #marginal='box', 
                   #y="No. of suicides per state", 
                   title='Distribution of Companies of Laptop',
                   color_discrete_sequence=['blue'])

fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f4f8a701-fed3-406a-bdea-10799b873eed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4f8a701-fed3-406a-bdea-10799b873eed")) {
#                     Plotly.newPlot(
#                         'f4f8a701-fed3-406a-bdea-10799b873eed',
# ...

# %%
py.plot(fig, filename="laptop7", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/23/'

# %%
fig = px.line_polar(df2, 
                    r="Price_euros",
                    theta="OpSys", 
                    color="Company", 
                    line_close=True,
                    color_discrete_sequence=px.colors.sequential.Plasma_r,
                    template="plotly_dark")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d839773-defd-4885-881f-fb497f852ea3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d839773-defd-4885-881f-fb497f852ea3")) {
#                     Plotly.newPlot(
#                         '2d839773-defd-4885-881f-fb497f852ea3',
# ...

# %%
py.plot(fig, filename="laptop8", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/25/'

# %%
fig = px.scatter(df2, 
                 x="Price_euros", 
                 y="Ram", 
                 animation_frame="Company", 
                 animation_group="OpSys",
#                  size="pop",     
                 color="Cpu", 
                 hover_name="Memory",
                 log_x=True, 
                 size_max=80, 
                 range_x=[200,2700], 
                 #range_y=[1,4]
                 )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="136a0d19-30df-41bd-ab17-550532ac9203" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("136a0d19-30df-41bd-ab17-550532ac9203")) {
#                     Plotly.newPlot(
#                         '136a0d19-30df-41bd-ab17-550532ac9203',
# ...

# %%
py.plot(fig, filename="laptop14", auto_open = True)
# Out:
# 'https://plotly.com/~pinaki2000/27/'
